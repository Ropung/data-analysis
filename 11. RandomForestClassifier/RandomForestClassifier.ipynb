# %% [markdown]
# # 와인 품종 분류

# %% [markdown]
# ### 1.1 패키지 로딩

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn import metrics
import pandas as pd

# %%
wine = load_wine()
# print(wine.DESCR)
X = wine.data
y = wine.target
df = pd.DataFrame(X, columns= wine.feature_names)
df['class'] =y
display(df.head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0    14.23        1.71  2.43               15.6      127.0           2.80  \
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0        3.06                  0.28             2.29             5.64  1.04  \
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %%
print(df['class'].value_counts())
# Out:
# class
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %% [markdown]
# ### 1.3 데이터 스케일링 및 분할

# %%
from sklearn.preprocessing import MinMaxScaler

scaled_X = MinMaxScaler().fit_transform(X)

X_train, X_test,y_train, y_test =train_test_split(scaled_X, y, test_size=0.3, random_state=10,stratify=y)
# X_train, X_test,y_train, y_test =train_test_split(X, y, test_size=0.3, random_state=10,stratify=y)

# %% [markdown]
# ### 모델 생성
# - RandomForestClassifier 파라메터
#   - bootstrap: 부트스트랩 사용여부(True이면 부트스트랩 표본으로 학습, False이면 표본 전체 이용하여 학습, default: True)
#   - criterion: 트리 분할에 사용할 알고리즘 (gini, entropy)
#   - max_depth: 나무의 최대 깊이
#   - min_samples_split: 노드를 분할하는데 필요한 최소 샘플 수
#   - n_estimators: 랜덤 포레스트 모델을 생성할 때 생성할 나무의 갯수 (defalut:100)

# %%
model = RandomForestClassifier(n_estimators=400)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=400)

# %% [markdown]
# ### 1.5 모델 평가

# %%
y_hat = model.predict(X_test)
print(f'정확도:{metrics.accuracy_score(y_test,y_hat):.3f}')
report = metrics.classification_report(y_test,y_hat)
print(report)
# Out:
# 정확도:1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54

# %% [markdown]
# ### 1.6 트리 시각화
# - graphviz 패키지 설치

# %%
from sklearn.tree import export_graphviz

estimator = model.estimators_[2]
export_graphviz(estimator, out_file='tree.dot',
                class_names=wine.target_names,
                feature_names=wine.feature_names,
                precision=3, #소수점 정밀도
                filled=True, # class별 색깔 채우기
                rounded=True, # box 모양을 둥글게
)

# %%
import graphviz

with open('tree.dot') as f:
  dot_graph = f.read()
graphviz.Source(dot_graph)

# %% [markdown]
# ## 하이퍼 파라미터 튜닝

# %%
from sklearn.model_selection import GridSearchCV

model = RandomForestClassifier()
params = {'max_depth':[6, 8, 10, 12, 16, 20, 24],
         'min_samples_split':[3, 6, 9, 12, 24],
         'n_estimators':[100, 200, 400, 500]}

grid_dtree = GridSearchCV(model, params, cv=5, scoring='accuracy')
grid_dtree.fit(scaled_X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [6, 8, 10, 12, 16, 20, 24],
#                          'min_samples_split': [3, 6, 9, 12, 24],
#                          'n_estimators': [100, 200, 400, 500]},
#              scoring='accuracy')

# %%
print(f'최적 파라미터:{grid_dtree.best_params_}')
print(f'최적 스코어:{grid_dtree.best_score_}')
# Out:
# 최적 파라미터:{'max_depth': 8, 'min_samples_split': 6, 'n_estimators': 200}
# 최적 스코어:0.9833333333333332

# %% [markdown]
# ### Feature Importance
# - Decision Tree 알고리즘이 학습을 통해 규칙을 정하는데 있어 피처의 중요한 역할 지표를 제공하는 속성
# - 일반적으로 값이 높을수록 해당 피처의 중요도가 높다는 의미로 해석

# %%
estimator = grid_dtree.best_estimator_
estimator.feature_importances_
# Out:
# array([0.11523463, 0.03418673, 0.00905189, 0.02827237, 0.02353095,
#        0.0513512 , 0.16298222, 0.00668543, 0.0220774 , 0.16241943,
#        0.06511004, 0.1199612 , 0.19913651])

# %%
importance = {k:v for k, v in zip(wine.feature_names, estimator.feature_importances_)}
df_importance = pd.DataFrame(pd.Series(importance), columns=['importance'])
df_importance = df_importance.sort_values('importance', ascending = False)
df_importance
# Out:
#                               importance
# proline                         0.199137
# flavanoids                      0.162982
# color_intensity                 0.162419
# od280/od315_of_diluted_wines    0.119961
# alcohol                         0.115235
# hue                             0.065110
# total_phenols                   0.051351
# malic_acid                      0.034187
# alcalinity_of_ash               0.028272
# magnesium                       0.023531
# proanthocyanins                 0.022077
# ash                             0.009052
# nonflavanoid_phenols            0.006685

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('default')
sns.barplot(data=df_importance, x='importance', y=df_importance.index)
plt.show()
