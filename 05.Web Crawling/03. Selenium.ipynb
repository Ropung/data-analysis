# %% [markdown]
# # Selenium
# - 크롤링이 목적이 아닌 웹 브라우저 테스트를 목적으로 만들어진 모듈
# - URL만으로는 접근할 수 없는 웹 페이지에 접근
# - 브라우저마다 WebDriver 설치 필요

# %% [markdown]
# ## 관련 패키지 설치

# %%
# !pip install selenium
# !pip install webdriver-manager

# %% [markdown]
# # webdriver 실행하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# 웹드라이버 동적 다운로드 방식으로 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
                         options=webdriver.ChromeOptions())

# 사전 설치된 웹 드라이버 클라이언트 프로그램 실행 방식
# driver = webdriver.Chrome(service=Service('c:\\Dev\\chromedriver_win32\\chromedriver.exe'))
driver.get('https://news.naver.com')
# 크롤링이 종료된 후 웹 드라이버 종료
# driver.close()
# Out:
# [WDM] - Downloading: 100%|██████████| 8.06M/8.06M [00:00<00:00, 11.2MB/s]

# %%
# find_element() 함수
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
# 웹드라이버 동적 다운로드 방식으로 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
                         options=webdriver.ChromeOptions())

driver.get('https://www.naver.com')
element = driver.find_element(by= By.ID, value = 'themecast')
print(type(element))
print(element.text)
# Out:
# <class 'selenium.webdriver.remote.webelement.WebElement'>
# 주제별 캐스트
# 오늘 읽을만한 글주제별로 분류된 다양한 글 모음
# 알림
# 654 개의 글 관심주제 설정
# 다음
# 엔터
# 스포츠
# 자동차
# 웹툰
# 경제
# 추천구독
# 레시피
# 리빙
# 결혼과 이혼 사이2ㅣ1화 선공개
# 결혼=악몽? 사이 타운에 입주한 위기의 부부들💥
# TVING
# 박하경 여행기| 캐릭터 인터랙티브 영상
# 8인 8색! 뭘 좋아할지 몰라서 다 준비했어🤗
# WAVVE
# 연예 홈
# 네이버 NOW.
# 네이버 TV홈
# TOP100
# 시리즈온
# VIBE
# 재생
# 재생시간
# 23:52
# TV 예능
# [하이라이트] ＂5번 타자도 문제없지💨＂ 몬스터즈 중심타선 다운 면모를 제-대로 보여주는 '정의윤' (vs 휘문고 2차전) | JTBC 230515 방송
# 8시간 전
# 최강야구
# 재생
# 재생시간
# 3:34
# TV 드라마
# [각성엔딩] 채정안, 의미심장한 말 던지는 장나라에 번뜩 떠오른 '27번' | tvN 230515 방송
# 11시간 전
# 패밀리
# 재생
# 재생시간
# 2:13
# TV 예능
# 강재준, 100일 만에 23kg 뺀 다이어트 비법!
# 10시간 전
# 동상이몽2_너는 내 운명
# 재생
# 재생시간
# 2:56
# TV 드라마
# [충격엔딩] 그토록 궁금했던 ‘파란 모자’와 마주한 김동욱?! | KBS 230515 방송
# 10시간 전
# 어쩌다 마주친, 그대
# 재생
# 재생시간
# 2:35
# TV 예능
# 몬스터즈 에이스 이대은✨ 공도 잘 던지고요 수비도 잘합니다! | JTBC 230515 방송
# 9시간 전
# 최강야구
# 재생
# 재생시간
# 2:40
# TV 예능
# 남자친구를 너무 사랑하는데.. 여자들이 계속 눈에 들어와요👀 | KBS Joy 230515 방송
# 12시간 전
# 무엇이든 물어보살
# 재생
# 재생시간
# 3:38
# TV 드라마
# [죽음 엔딩] “지금 이 모습이 너의 진짜 얼굴이니라” 강훈의 칼날에 죽음을 맞이한 오만석
# 10시간 전
# 꽃선비 열애사
# 재생
# 재생시간
# 2:16
# TV 예능
# [선공개] 이거슨 데스~티니? 스리랑카에서 재회한 김숙 X 동원 조카♥ MBN 230516 방송
# 12시간 전
# 지구탐구생활
# 재생
# 재생시간
# 0:34
# TV 드라마
# [최종회 예고] “항복한다면 죽이진 않겠소” 려운, 왕위를 되찾기 위한 현우와 마지막 대결♨
# 10시간 전
# 꽃선비 열애사
# 뮤직 급상승 차트
# 오후 6시 업데이트
# 1
# 위
# 퀸카 (Queencard)
# (여자)아이들 I feel
# 재생
# 가사
# 2
# 위
# 상승
# Allergy
# (여자)아이들 I feel
# 재생
# 가사
# 3
# 위
# 상승
# 부동의 첫사랑
# 10CM 5.4 [부동의 첫사랑]
# 재생
# 가사
# 4
# 위
# 사랑..그게 뭔데
# 지아 사랑..그게 뭔데
# 재생
# 가사
# 5
# 위
# 상승
# 사랑이 이별이 돼 가는 모습이
# 볼빨간사춘기 사랑.zip
# 재생
# 가사
# 6
# 위
# 상승
# Salty & Sweet
# aespa MY WORLD - The 3rd Mini Album
# 재생
# 가사
# 7
# 위
# 하락
# Spicy
# aespa MY WORLD - The 3rd Mini Album
# 재생
# 가사
# 8
# 위
# 상승
# 나는
# 태양 Down to Earth
# 재생
# 가사
# 9
# 위
# 금지된 사랑
# 반하나 금지된 사랑
# 재생
# 가사
# 10
# 위
# 상승
# Nightfall (feat. Bryan Chase)
# 태양 Down to Earth
# 재생
# 가사
# 재생
# 재생시간
# 2:40
# TV 드라마
# [결혼과 이혼 사이2] 결혼=악몽? 사이 타운에 입주한 위기의 부부들💥ㅣ1화 선공개
# 23시간 전
# 티빙(TVING)
# 재생
# 재생시간
# 2:27
# TV 예능
# 세계에서 가장 큰 악어와 함께 수영을♪ 찐으로 놀란 이찬원😲 | JTBC 230515 방송
# 12시간 전
# 톡파원 25시
# 재생
# 재생시간
# 2:11
# TV 드라마
# 남기애, 신예은에 건네는 비밀 교지!
# 10시간 전
# 꽃선비 열애사
# 재생
# 재생시간
# 0:23
# TV 드라마
# [45회 예고] 미안해 아직은 내 정체를 밝힐 수 없어 | KBS 방송
# 12시간 전
# 비밀의 여자
# 재생
# 재생시간
# 3:40
# TV 예능
# ‘열혈 워킹맘’ 이현이, 피로 풀 시간 없는 열일 루틴!
# 9시간 전
# 동상이몽2_너는 내 운명
# 재생
# 재생시간
# 3:38
# TV 예능
# 이현이, 캠핑장에서도 이어지는 홍성기 생색에 쌓이는 분노♨
# 9시간 전
# 동상이몽2_너는 내 운명
# 재생
# 재생시간
# 3:26
# TV 드라마
# “당장 저놈의 사지를 찢어라” 현우, 정건주에게 내리는 거열형
# 10시간 전
# 꽃선비 열애사
# 재생
# 재생시간
# 9:44
# TV 예능
# [클로징] ＂셋 다 주자＂ 연장전을 피한 김성근 감독님의 통 큰 MVP 뽑기? | JTBC 230515 방송
# 9시간 전
# 최강야구
# 재생
# 재생시간
# 9:48
# TV 드라마
# 9화#하이라이트# 국가 비밀 조합의 와해로 희생 당한 조합원들
# 11시간 전
# 패밀리
# VIBE MAG
# 다음
# New Release #143 : 에스파, 조나스 브라더스
# 2023.05.15
# 한국 힙합 여기요 : 애쉬 아일랜드, 미란이
# 2023.05.12
# 이주의 디깅 #158 다프트 펑크
# 2023.05.11
# 당신의 눈과 귀를 사로잡을 로맨스 <남은 인생 10년>
# 2023.05.10
# 딴따라 아이콘의 유쾌한 컴백
# 2023.05.08
# 새로운 글 더보기

# %% [markdown]
# # 이벤트 제어

# %% [markdown]
# ## click()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# 웹드라이버 동적 다운로드 방식으로 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
options=webdriver.ChromeOptions())

driver.get('https://www.naver.com')

element = driver.find_element(by=By.CLASS_NAME,value='link_media')
element.click()
# Out:
# [WDM] - Downloading: 100%|██████████| 8.06M/8.06M [00:00<00:00, 10.9MB/s]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 웹드라이버 동적 다운로드 방식으로 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
options=webdriver.ChromeOptions())
driver.get('https://www.naver.com')
element = driver.find_element(by=By.CLASS_NAME,value='link_login')
element.click()

# my_id = 'test'
# my_pw = 'test'

# time.sleep(1)
# element = driver.find_element_by_id('id')
# element.send_keys(my_id)

# element = driver.find_element_by_id('pw')
# element.send_keys(my_pw)

#로봇에 의해 클릭되지 못하도록 막아놨기 때문에 스크립로 처리하여 로그인
driver.execute_script(f"document.getElementById('id').value = '{'asdf1234'}'")
driver.execute_script(f"document.getElementById('pw').value = '{'asdf1234@'}'")

element =driver.execute_script(f"document.getElementById('keep').value ='on'")

element = driver.find_element(by=By.CLASS_NAME,value='btn_login')
element.click()

# %% [markdown]
# # 5. 웹 브라우저 자동 스크롤
# ### 구글에서 이미지 검색 후 검색 결과 6번 스크롤 하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

#  페이지가 로드될떄까지 기다리는 시간
SCROLL_PAUSE_TIME = 1
SEARCH_KEY_WORD =  'python'

# 웹드라이버 동적 다운로드 방식으로 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
options=webdriver.ChromeOptions())
driver.get('https://www.google.com')

element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEY_WORD)
element.submit()

driver.find_element(By.LINK_TEXT,'이미지').click()
# 페이지가 로드될떄까지 기다림
time.sleep(SCROLL_PAUSE_TIME)
last_height = driver.execute_script('return document.body.scrollHeight')
print('last height: ',last_height)

for i in range(6):
  # 윈도우 창을 0에서부터 가장 밑(scrollHeight) 까지 이동
  driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
  time.sleep(SCROLL_PAUSE_TIME)
  new_height = driver.execute_script('return document.body.scrollHeight')
  # 더 이상 스크롤 될 페이지가 없을 경우 scrollHeight 값의 변화가 없다.
  print('new height: ',new_height)
  print('-'*30)
# Out:
# last height:  3270
# new height:  6670
# ------------------------------
# new height:  13462
# ------------------------------
# new height:  19770
# ------------------------------
# new height:  26078
# ------------------------------
# new height:  26159
# ------------------------------
# new height:  26159
# ------------------------------

# %% [markdown]
# ### 구글에서 이미지 검색 후 검색 결과 무한 스크롤 하기
# - step 1:

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

#  페이지가 로드될떄까지 기다리는 시간
SCROLL_PAUSE_TIME = 1
SEARCH_KEY_WORD =  'python'

# 웹드라이버 동적 다운로드 방식으로 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
options=webdriver.ChromeOptions())
driver.get('https://www.google.com')

element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEY_WORD)
element.submit()

driver.find_element(By.LINK_TEXT,'이미지').click()
# 페이지가 로드될떄까지 기다림
time.sleep(SCROLL_PAUSE_TIME)
last_height = driver.execute_script('return document.body.scrollHeight')

# 스크롤 횟수
scroll_cnt = 1

while True:
  # 윈도우 창을 0에서부터 가장 밑(scrollHeight) 까지 이동
  driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
  time.sleep(SCROLL_PAUSE_TIME)
  new_height = driver.execute_script('return document.body.scrollHeight')
  # 더 이상 스크롤 될 페이지가 없을 경우 scrollHeight 값의 변화가 없다.
  print(f'last height:{last_height},new_height:{new_height},scroll count:{scroll_cnt}')
  print('-'*30)
  # 계속해서 new_height의 값이 변경 된다면
  if last_height != new_height:
    last_height = new_height
    scroll_cnt +=1
  else: # 더이상 new_height 값의 변동이 없다면
    element=driver.find_element(By.CSS_SELECTOR, '#islmp > div > div> div> div > div.gBPM8 > div.qvfT1 > div.YstHxe > input')
    # 해당 엘리먼트와 상호작용이 불가한 상태가 되면 예외 발생
    try:
      element.click()
      print('결과 더보기 클릭!')
    except:
      break
# Out:
# last height:3274,new_height:6670,scroll count:1
# ------------------------------
# last height:6670,new_height:12978,scroll count:2
# ------------------------------
# last height:12978,new_height:19528,scroll count:3
# ------------------------------
# last height:19528,new_height:26078,scroll count:4
# ------------------------------
# last height:26078,new_height:26159,scroll count:5
# ------------------------------
# last height:26159,new_height:26159,scroll count:6
# ------------------------------
# 결과 더보기 클릭!
# last height:26159,new_height:29308,scroll count:6
# ------------------------------
# last height:29308,new_height:29308,scroll count:7
# ------------------------------

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

#  페이지가 로드될떄까지 기다리는 시간
SCROLL_PAUSE_TIME = 1
IMAGE_LIMIT = 10
SEARCH_KEY_WORD =  'python'

# 웹드라이버 동적 다운로드 방식으로 실행
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
options=webdriver.ChromeOptions())
driver.get('https://www.google.com')

element = driver.find_element(by=By.CLASS_NAME, value='gLFyf')
element.send_keys(SEARCH_KEY_WORD)
element.submit()

driver.find_element(By.LINK_TEXT,'이미지').click()
# 페이지가 로드될떄까지 기다림
time.sleep(SCROLL_PAUSE_TIME)
last_height = driver.execute_script('return document.body.scrollHeight')

# 스크롤 횟수
scroll_cnt = 1

while True:
  # 윈도우 창을 0에서부터 가장 밑(scrollHeight) 까지 이동
  driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
  time.sleep(SCROLL_PAUSE_TIME)
  new_height = driver.execute_script('return document.body.scrollHeight')
  # 더 이상 스크롤 될 페이지가 없을 경우 scrollHeight 값의 변화가 없다.
  print(f'last height:{last_height},new_height:{new_height},scroll count:{scroll_cnt}')
  print('-'*30)
  # 계속해서 new_height의 값이 변경 된다면
  if last_height != new_height:
    last_height = new_height
    scroll_cnt +=1
  else: # 더이상 new_height 값의 변동이 없다면
    element=driver.find_element(By.CSS_SELECTOR, '#islmp > div > div> div> div > div.gBPM8 > div.qvfT1 > div.YstHxe > input')
    # 해당 엘리먼트와 상호작용이 불가한 상태가 되면 예외 발생
    try:
      element.click()
      print('결과 더보기 클릭!')
    except:
      break

# 이미지 선택 & 해당 이미지에 src 저장
imgs = driver.find_element(By.CSS_SELECTOR,'#islrg > div.islrc > div:nth-child(54) > div.isv-r.PNCib.MSM1fd.BUooTd.fT6ABc > a.wXeWr.islib.nfEiy')
